# %%
from dateutil.parser import parse as parse_date
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
import spotipy
import spotipy.util as util
user_id = '1221063701'
client_id = 'a4a8320b97e84b88bc8f4585251085ce'
client_secret = '57f7dc998a714c61b8391858bdc5cc7c'
playlist_id = '5W9K5hiEUI2r7uj9VpX3Z2?si=fndGCxUVRAmIzkbWSEz3Zw'


token = util.prompt_for_user_token(user_id,
                                   'playlist-read-collaborative',
                                   client_id=client_id,
                                   client_secret=client_secret,
                                   redirect_uri='https://www.facebook.com/groups/1223037501082162')
sp = spotipy.Spotify(auth=token)

# %%
playlist = sp.user_playlist(user_id, playlist_id)
tracks = playlist['tracks']['items']
next_uri = playlist['tracks']['next']
for _ in range(int(playlist['tracks']['total'] / playlist['tracks']['limit'])):
    response = sp._get(next_uri)
    tracks += response['items']
    next_uri = response['next']

tracks_df = pd.DataFrame([(track['track']['id'],
                           track['track']['artists'][0]['name'],
                           track['track']['name'],
                           track['track']['popularity'],
                           parse_date(track['track']['album']['release_date']) if track['track']['album']['release_date'] else None,
                           parse_date(track['added_at']))
                          for track in playlist['tracks']['items']],
                         columns=['id', 'artist', 'name', 'popularity','release_date', 'added_at'] )

# %%
tracks_df
# Out:
#                         id                            artist  \
# 0   2Lk8XTulavagQOrYqFpGB8                     Billy Strings
# 1   2NGUXjeXcriG5O3ud1SNcm                  Sturgill Simpson
# 2   2su9lOnI21rEmHdBcWjM2B                  Sturgill Simpson
# 3   3QUG2aFOmRx48Zb2QChnoy  Black Joe Lewis & The Honeybears
# 4   4JpazKcfOhbwqZrsYhzHee                            Hozier
# 5   6PT1dLDHk9BaVwFG74pomG                  Sturgill Simpson
# 6   4xvB0wcMmNn7lcw1boRoA0                              GRiZ
# 7   4dhARBZ8YLvm8oRDnCIeXr          Unknown Mortal Orchestra
# 8   26V4mdiCfPc5rQfhoRCo9j   J. Roddy Walston & The Business
# 9   0z2TpISFncJ0F83Y5ZQciF                            Cherub
# 10  1nj3fP1BRNJWfWZOFZ56nu                        Psymbionic
# 11  0UYz2MYHwUSSquqdDIJc0j                  Charley Crockett
# 12  4B9v2AXBpnA5tBhGTaQG0G                      Paul Cauthen
# 13  0MJ5Qltavj6AWdxjheHlSI                 The Wood Brothers
# 14  4M8OfVBpn4OHeDsEgOE50w                      Robert Ellis
# 15  5VzbhVg77OSCpuMDfjdL72                       Alina Baraz
# 16  6YDf6QV7QfCEo8O2dbWalK                 Father John Misty
# 17  2R4O7MgIrN35QXnyLKMFVl                      Leon Bridges
# 18  3MLmUZ3cd1zBHJa7A5IMOM          Grady Spencer & the Work
# 19  2Y61ZvCuuLOhdkgl1B9ekh                  Michael Kiwanuka
# 20  1torCG1rbtUN5ja5lnv7rX                      Sara Watkins
# 21  0UC0BEEYZgns2cGQo8Dqpy                    Gary Clark Jr.
# 22  4vtyIW5uMCzu827nc5ThVt                   Brittany Howard
# 23  6UKG36P9ExFQpmNNjoCX9X                      Grace Potter
#
#                                                 name  popularity release_date  \
# 0                                   Dust in a Baggie          58   2016-06-10
# 1              Life Ain’t Fair and the World Is Mean          56   2020-10-16
# 2                                     All Around You          61   2020-10-16
# 3                                        Get Yo Shit          48   2009-01-12
# 4                                  Jackie and Wilson          64   2014-09-19
# 5                              Mercury in Retrograde          54   2019-09-27
# 6                                    Where Will I Go          41   2020-09-17
# 7                                     Necessary Evil          62   2015-05-26
# 8                                  Brave Man's Death          41   2010-07-27
# 9                                        Doo Doo Doo          39   2020-07-03
# 10  One Thing (feat. Cristina Soto) - Amp Live Remix          49   2014-12-09
# 11                                      In the Night          51   2016-06-06
# 12                           Cocaine Country Dancing          59   2019-09-06
# 13                                      I Got Loaded          61   2013-01-12
# 14                             Nobody Smokes Anymore          29   2019-02-14
# 15                                     Make You Feel          60   2015-05-19
# 16                                    Real Love Baby          46   2016-07-26
# 17                                              Mrs.          60   2018-05-04
# 18                                    Nothing Is Bad          54   2016-04-22
# 19                                              Hero          60   2019-10-10
# 20                                           Move Me          35   2016-07-01
# 21                                    The Guitar Man          38   2019-02-22
# 22                                         Stay High          59   2019-09-20
# 23                         Reposession [Feat Lucius]          29   2019-10-25
#
#                     added_at
# 0  2020-10-10 00:56:10+00:00
# 1  2020-10-20 22:10:17+00:00
# 2  2020-10-21 02:23:13+00:00
# 3  2020-10-21 02:27:13+00:00
# 4  2020-10-21 02:40:59+00:00
# 5  2020-10-24 15:19:26+00:00
# 6  2020-10-28 02:21:39+00:00
# 7  2020-10-24 03:10:23+00:00
# 8  2020-10-31 20:27:47+00:00
# 9  2020-11-10 00:49:39+00:00
# 10 2020-11-12 21:24:42+00:00
# 11 2021-01-07 21:40:30+00:00
# 12 2021-01-07 21:40:40+00:00
# 13 2021-01-07 21:41:26+00:00
# 14 2021-01-07 21:41:36+00:00
# 15 2021-01-07 21:42:26+00:00
# 16 2021-01-07 21:44:07+00:00
# 17 2021-01-07 21:44:52+00:00
# 18 2021-01-07 21:47:50+00:00
# 19 2021-01-07 21:52:51+00:00
# 20 2021-01-07 21:55:30+00:00
# 21 2021-01-07 21:58:31+00:00
# 22 2021-01-07 21:59:03+00:00
# 23 2021-01-07 22:00:00+00:00

# %%
tracks_df \
    .groupby('artist') \
    .count()['id'] \
    .reset_index() \
    .sort_values('id', ascending=False) \
    .rename(columns={'id': 'amount'}) \
    .head(10)
# Out:
#                artist  amount
# 19   Sturgill Simpson       3
# 0         Alina Baraz       1
# 1       Billy Strings       1
# 20  The Wood Brothers       1
# 18       Sara Watkins       1
# 17       Robert Ellis       1
# 16         Psymbionic       1
# 15       Paul Cauthen       1
# 14   Michael Kiwanuka       1
# 13       Leon Bridges       1

# %%
song_ids = pd.DataFrame(tracks_df, columns= ['id'])
song_ids
# song_id_list = song_ids.values.tolist()
# slice(song_id_list)
# print(song_id_list)
# Out:
#                         id
# 0   2Lk8XTulavagQOrYqFpGB8
# 1   2NGUXjeXcriG5O3ud1SNcm
# 2   2su9lOnI21rEmHdBcWjM2B
# 3   3QUG2aFOmRx48Zb2QChnoy
# 4   4JpazKcfOhbwqZrsYhzHee
# 5   6PT1dLDHk9BaVwFG74pomG
# 6   4xvB0wcMmNn7lcw1boRoA0
# 7   4dhARBZ8YLvm8oRDnCIeXr
# 8   26V4mdiCfPc5rQfhoRCo9j
# 9   0z2TpISFncJ0F83Y5ZQciF
# 10  1nj3fP1BRNJWfWZOFZ56nu
# 11  0UYz2MYHwUSSquqdDIJc0j
# 12  4B9v2AXBpnA5tBhGTaQG0G
# 13  0MJ5Qltavj6AWdxjheHlSI
# 14  4M8OfVBpn4OHeDsEgOE50w
# 15  5VzbhVg77OSCpuMDfjdL72
# 16  6YDf6QV7QfCEo8O2dbWalK
# 17  2R4O7MgIrN35QXnyLKMFVl
# 18  3MLmUZ3cd1zBHJa7A5IMOM
# 19  2Y61ZvCuuLOhdkgl1B9ekh
# 20  1torCG1rbtUN5ja5lnv7rX
# 21  0UC0BEEYZgns2cGQo8Dqpy
# 22  4vtyIW5uMCzu827nc5ThVt
# 23  6UKG36P9ExFQpmNNjoCX9X

# %%
results = sp.audio_features(song_ids['id'])
results
# Out:
# [{'danceability': 0.519,
#   'energy': 0.776,
#   'key': 7,
#   'loudness': -7.051,
#   'mode': 1,
#   'speechiness': 0.0309,
#   'acousticness': 0.252,
#   'instrumentalness': 2.92e-05,
#   'liveness': 0.157,
#   'valence': 0.653,
#   'tempo': 137.29,
#   'type': 'audio_features',
#   'id': '2Lk8XTulavagQOrYqFpGB8',
#   'uri': 'spotify:track:2Lk8XTulavagQOrYqFpGB8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Lk8XTulavagQOrYqFpGB8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Lk8XTulavagQOrYqFpGB8',
#   'duration_ms': 174173,
#   'time_signature': 4},
#  {'danceability': 0.764,
#   'energy': 0.658,
#   'key': 4,
#   'loudness': -7.228,
#   'mode': 1,
#   'speechiness': 0.0471,
#   'acousticness': 0.613,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.853,
#   'tempo': 107.89,
#   'type': 'audio_features',
#   'id': '2NGUXjeXcriG5O3ud1SNcm',
#   'uri': 'spotify:track:2NGUXjeXcriG5O3ud1SNcm',
#   'track_href': 'https://api.spotify.com/v1/tracks/2NGUXjeXcriG5O3ud1SNcm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NGUXjeXcriG5O3ud1SNcm',
#   'duration_ms': 120533,
#   'time_signature': 4},
#  {'danceability': 0.663,
#   'energy': 0.628,
#   'key': 11,
#   'loudness': -8.824,
#   'mode': 1,
#   'speechiness': 0.0293,
#   'acousticness': 0.614,
#   'instrumentalness': 0.578,
#   'liveness': 0.355,
#   'valence': 0.433,
#   'tempo': 97.305,
#   'type': 'audio_features',
#   'id': '2su9lOnI21rEmHdBcWjM2B',
#   'uri': 'spotify:track:2su9lOnI21rEmHdBcWjM2B',
#   'track_href': 'https://api.spotify.com/v1/tracks/2su9lOnI21rEmHdBcWjM2B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2su9lOnI21rEmHdBcWjM2B',
#   'duration_ms': 189013,
#   'time_signature': 3},
#  {'danceability': 0.709,
#   'energy': 0.601,
#   'key': 11,
#   'loudness': -3.877,
#   'mode': 0,
#   'speechiness': 0.0374,
#   'acousticness': 0.00921,
#   'instrumentalness': 0,
#   'liveness': 0.0736,
#   'valence': 0.717,
#   'tempo': 113.044,
#   'type': 'audio_features',
#   'id': '3QUG2aFOmRx48Zb2QChnoy',
#   'uri': 'spotify:track:3QUG2aFOmRx48Zb2QChnoy',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QUG2aFOmRx48Zb2QChnoy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QUG2aFOmRx48Zb2QChnoy',
#   'duration_ms': 167800,
#   'time_signature': 4},
#  {'danceability': 0.555,
#   'energy': 0.727,
#   'key': 6,
#   'loudness': -4.202,
#   'mode': 1,
#   'speechiness': 0.0388,
#   'acousticness': 0.0579,
#   'instrumentalness': 7.52e-06,
#   'liveness': 0.0937,
#   'valence': 0.739,
#   'tempo': 82.142,
#   'type': 'audio_features',
#   'id': '4JpazKcfOhbwqZrsYhzHee',
#   'uri': 'spotify:track:4JpazKcfOhbwqZrsYhzHee',
#   'track_href': 'https://api.spotify.com/v1/tracks/4JpazKcfOhbwqZrsYhzHee',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JpazKcfOhbwqZrsYhzHee',
#   'duration_ms': 223120,
#   'time_signature': 4},
#  {'danceability': 0.713,
#   'energy': 0.74,
#   'key': 4,
#   'loudness': -5.281,
#   'mode': 1,
#   'speechiness': 0.0384,
#   'acousticness': 0.0141,
#   'instrumentalness': 0.000429,
#   'liveness': 0.717,
#   'valence': 0.939,
#   'tempo': 125.028,
#   'type': 'audio_features',
#   'id': '6PT1dLDHk9BaVwFG74pomG',
#   'uri': 'spotify:track:6PT1dLDHk9BaVwFG74pomG',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PT1dLDHk9BaVwFG74pomG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PT1dLDHk9BaVwFG74pomG',
#   'duration_ms': 271588,
#   'time_signature': 4},
#  {'danceability': 0.399,
#   'energy': 0.875,
#   'key': 6,
#   'loudness': -6.109,
#   'mode': 1,
#   'speechiness': 0.0398,
#   'acousticness': 0.000111,
#   'instrumentalness': 0.772,
#   'liveness': 0.0985,
#   'valence': 0.357,
#   'tempo': 165.95,
#   'type': 'audio_features',
#   'id': '4xvB0wcMmNn7lcw1boRoA0',
#   'uri': 'spotify:track:4xvB0wcMmNn7lcw1boRoA0',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xvB0wcMmNn7lcw1boRoA0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xvB0wcMmNn7lcw1boRoA0',
#   'duration_ms': 196627,
#   'time_signature': 4},
#  {'danceability': 0.828,
#   'energy': 0.724,
#   'key': 9,
#   'loudness': -7.217,
#   'mode': 1,
#   'speechiness': 0.113,
#   'acousticness': 0.045,
#   'instrumentalness': 0.0618,
#   'liveness': 0.132,
#   'valence': 0.694,
#   'tempo': 96.2,
#   'type': 'audio_features',
#   'id': '4dhARBZ8YLvm8oRDnCIeXr',
#   'uri': 'spotify:track:4dhARBZ8YLvm8oRDnCIeXr',
#   'track_href': 'https://api.spotify.com/v1/tracks/4dhARBZ8YLvm8oRDnCIeXr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dhARBZ8YLvm8oRDnCIeXr',
#   'duration_ms': 317800,
#   'time_signature': 4},
#  {'danceability': 0.531,
#   'energy': 0.879,
#   'key': 3,
#   'loudness': -5.541,
#   'mode': 1,
#   'speechiness': 0.0472,
#   'acousticness': 0.337,
#   'instrumentalness': 0,
#   'liveness': 0.596,
#   'valence': 0.791,
#   'tempo': 140.907,
#   'type': 'audio_features',
#   'id': '26V4mdiCfPc5rQfhoRCo9j',
#   'uri': 'spotify:track:26V4mdiCfPc5rQfhoRCo9j',
#   'track_href': 'https://api.spotify.com/v1/tracks/26V4mdiCfPc5rQfhoRCo9j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/26V4mdiCfPc5rQfhoRCo9j',
#   'duration_ms': 321240,
#   'time_signature': 4},
#  {'danceability': 0.544,
#   'energy': 0.835,
#   'key': 2,
#   'loudness': -4.446,
#   'mode': 1,
#   'speechiness': 0.0526,
#   'acousticness': 0.0736,
#   'instrumentalness': 0,
#   'liveness': 0.142,
#   'valence': 0.67,
#   'tempo': 178.129,
#   'type': 'audio_features',
#   'id': '0z2TpISFncJ0F83Y5ZQciF',
#   'uri': 'spotify:track:0z2TpISFncJ0F83Y5ZQciF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0z2TpISFncJ0F83Y5ZQciF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0z2TpISFncJ0F83Y5ZQciF',
#   'duration_ms': 186426,
#   'time_signature': 4},
#  {'danceability': 0.548,
#   'energy': 0.731,
#   'key': 8,
#   'loudness': -6.287,
#   'mode': 0,
#   'speechiness': 0.0334,
#   'acousticness': 9.47e-05,
#   'instrumentalness': 0.0118,
#   'liveness': 0.361,
#   'valence': 0.484,
#   'tempo': 156.968,
#   'type': 'audio_features',
#   'id': '1nj3fP1BRNJWfWZOFZ56nu',
#   'uri': 'spotify:track:1nj3fP1BRNJWfWZOFZ56nu',
#   'track_href': 'https://api.spotify.com/v1/tracks/1nj3fP1BRNJWfWZOFZ56nu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1nj3fP1BRNJWfWZOFZ56nu',
#   'duration_ms': 261401,
#   'time_signature': 4},
#  {'danceability': 0.688,
#   'energy': 0.711,
#   'key': 3,
#   'loudness': -4.928,
#   'mode': 0,
#   'speechiness': 0.0251,
#   'acousticness': 0.186,
#   'instrumentalness': 1.96e-05,
#   'liveness': 0.14,
#   'valence': 0.707,
#   'tempo': 95.742,
#   'type': 'audio_features',
#   'id': '0UYz2MYHwUSSquqdDIJc0j',
#   'uri': 'spotify:track:0UYz2MYHwUSSquqdDIJc0j',
#   'track_href': 'https://api.spotify.com/v1/tracks/0UYz2MYHwUSSquqdDIJc0j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0UYz2MYHwUSSquqdDIJc0j',
#   'duration_ms': 236070,
#   'time_signature': 4},
#  {'danceability': 0.776,
#   'energy': 0.582,
#   'key': 2,
#   'loudness': -8.726,
#   'mode': 1,
#   'speechiness': 0.0684,
#   'acousticness': 0.331,
#   'instrumentalness': 0.427,
#   'liveness': 0.0926,
#   'valence': 0.585,
#   'tempo': 92.032,
#   'type': 'audio_features',
#   'id': '4B9v2AXBpnA5tBhGTaQG0G',
#   'uri': 'spotify:track:4B9v2AXBpnA5tBhGTaQG0G',
#   'track_href': 'https://api.spotify.com/v1/tracks/4B9v2AXBpnA5tBhGTaQG0G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4B9v2AXBpnA5tBhGTaQG0G',
#   'duration_ms': 256281,
#   'time_signature': 4},
#  {'danceability': 0.76,
#   'energy': 0.428,
#   'key': 9,
#   'loudness': -8.768,
#   'mode': 1,
#   'speechiness': 0.0347,
#   'acousticness': 0.357,
#   'instrumentalness': 0.000351,
#   'liveness': 0.0753,
#   'valence': 0.459,
#   'tempo': 108.574,
#   'type': 'audio_features',
#   'id': '0MJ5Qltavj6AWdxjheHlSI',
#   'uri': 'spotify:track:0MJ5Qltavj6AWdxjheHlSI',
#   'track_href': 'https://api.spotify.com/v1/tracks/0MJ5Qltavj6AWdxjheHlSI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MJ5Qltavj6AWdxjheHlSI',
#   'duration_ms': 243440,
#   'time_signature': 4},
#  {'danceability': 0.598,
#   'energy': 0.705,
#   'key': 5,
#   'loudness': -7.153,
#   'mode': 1,
#   'speechiness': 0.0513,
#   'acousticness': 0.16,
#   'instrumentalness': 7.67e-06,
#   'liveness': 0.122,
#   'valence': 0.278,
#   'tempo': 135.415,
#   'type': 'audio_features',
#   'id': '4M8OfVBpn4OHeDsEgOE50w',
#   'uri': 'spotify:track:4M8OfVBpn4OHeDsEgOE50w',
#   'track_href': 'https://api.spotify.com/v1/tracks/4M8OfVBpn4OHeDsEgOE50w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4M8OfVBpn4OHeDsEgOE50w',
#   'duration_ms': 204493,
#   'time_signature': 4},
#  {'danceability': 0.7,
#   'energy': 0.43,
#   'key': 1,
#   'loudness': -8.437,
#   'mode': 0,
#   'speechiness': 0.0399,
#   'acousticness': 0.787,
#   'instrumentalness': 0.000476,
#   'liveness': 0.129,
#   'valence': 0.103,
#   'tempo': 100.008,
#   'type': 'audio_features',
#   'id': '5VzbhVg77OSCpuMDfjdL72',
#   'uri': 'spotify:track:5VzbhVg77OSCpuMDfjdL72',
#   'track_href': 'https://api.spotify.com/v1/tracks/5VzbhVg77OSCpuMDfjdL72',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5VzbhVg77OSCpuMDfjdL72',
#   'duration_ms': 220800,
#   'time_signature': 4},
#  {'danceability': 0.417,
#   'energy': 0.686,
#   'key': 7,
#   'loudness': -6.484,
#   'mode': 1,
#   'speechiness': 0.0373,
#   'acousticness': 0.0955,
#   'instrumentalness': 0.0287,
#   'liveness': 0.0989,
#   'valence': 0.625,
#   'tempo': 204.113,
#   'type': 'audio_features',
#   'id': '6YDf6QV7QfCEo8O2dbWalK',
#   'uri': 'spotify:track:6YDf6QV7QfCEo8O2dbWalK',
#   'track_href': 'https://api.spotify.com/v1/tracks/6YDf6QV7QfCEo8O2dbWalK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6YDf6QV7QfCEo8O2dbWalK',
#   'duration_ms': 189293,
#   'time_signature': 4},
#  {'danceability': 0.705,
#   'energy': 0.354,
#   'key': 6,
#   'loudness': -9.592,
#   'mode': 1,
#   'speechiness': 0.29,
#   'acousticness': 0.479,
#   'instrumentalness': 0,
#   'liveness': 0.0734,
#   'valence': 0.376,
#   'tempo': 119.789,
#   'type': 'audio_features',
#   'id': '2R4O7MgIrN35QXnyLKMFVl',
#   'uri': 'spotify:track:2R4O7MgIrN35QXnyLKMFVl',
#   'track_href': 'https://api.spotify.com/v1/tracks/2R4O7MgIrN35QXnyLKMFVl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2R4O7MgIrN35QXnyLKMFVl',
#   'duration_ms': 242520,
#   'time_signature': 3},
#  {'danceability': 0.552,
#   'energy': 0.689,
#   'key': 1,
#   'loudness': -4.92,
#   'mode': 0,
#   'speechiness': 0.0442,
#   'acousticness': 0.224,
#   'instrumentalness': 0.000182,
#   'liveness': 0.116,
#   'valence': 0.471,
#   'tempo': 169.729,
#   'type': 'audio_features',
#   'id': '3MLmUZ3cd1zBHJa7A5IMOM',
#   'uri': 'spotify:track:3MLmUZ3cd1zBHJa7A5IMOM',
#   'track_href': 'https://api.spotify.com/v1/tracks/3MLmUZ3cd1zBHJa7A5IMOM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3MLmUZ3cd1zBHJa7A5IMOM',
#   'duration_ms': 245907,
#   'time_signature': 4},
#  {'danceability': 0.532,
#   'energy': 0.942,
#   'key': 4,
#   'loudness': -3.395,
#   'mode': 0,
#   'speechiness': 0.0348,
#   'acousticness': 0.0232,
#   'instrumentalness': 0.848,
#   'liveness': 0.104,
#   'valence': 0.533,
#   'tempo': 95.065,
#   'type': 'audio_features',
#   'id': '2Y61ZvCuuLOhdkgl1B9ekh',
#   'uri': 'spotify:track:2Y61ZvCuuLOhdkgl1B9ekh',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Y61ZvCuuLOhdkgl1B9ekh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Y61ZvCuuLOhdkgl1B9ekh',
#   'duration_ms': 199133,
#   'time_signature': 4},
#  {'danceability': 0.488,
#   'energy': 0.537,
#   'key': 0,
#   'loudness': -8.375,
#   'mode': 0,
#   'speechiness': 0.0265,
#   'acousticness': 0.261,
#   'instrumentalness': 0.00683,
#   'liveness': 0.101,
#   'valence': 0.467,
#   'tempo': 79.545,
#   'type': 'audio_features',
#   'id': '1torCG1rbtUN5ja5lnv7rX',
#   'uri': 'spotify:track:1torCG1rbtUN5ja5lnv7rX',
#   'track_href': 'https://api.spotify.com/v1/tracks/1torCG1rbtUN5ja5lnv7rX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1torCG1rbtUN5ja5lnv7rX',
#   'duration_ms': 346507,
#   'time_signature': 4},
#  {'danceability': 0.481,
#   'energy': 0.83,
#   'key': 5,
#   'loudness': -4.681,
#   'mode': 1,
#   'speechiness': 0.0387,
#   'acousticness': 0.0608,
#   'instrumentalness': 0,
#   'liveness': 0.296,
#   'valence': 0.597,
#   'tempo': 87.843,
#   'type': 'audio_features',
#   'id': '0UC0BEEYZgns2cGQo8Dqpy',
#   'uri': 'spotify:track:0UC0BEEYZgns2cGQo8Dqpy',
#   'track_href': 'https://api.spotify.com/v1/tracks/0UC0BEEYZgns2cGQo8Dqpy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0UC0BEEYZgns2cGQo8Dqpy',
#   'duration_ms': 266973,
#   'time_signature': 4},
#  {'danceability': 0.598,
#   'energy': 0.853,
#   'key': 9,
#   'loudness': -5.373,
#   'mode': 1,
#   'speechiness': 0.0546,
#   'acousticness': 0.132,
#   'instrumentalness': 0.00298,
#   'liveness': 0.132,
#   'valence': 0.315,
#   'tempo': 122.012,
#   'type': 'audio_features',
#   'id': '4vtyIW5uMCzu827nc5ThVt',
#   'uri': 'spotify:track:4vtyIW5uMCzu827nc5ThVt',
#   'track_href': 'https://api.spotify.com/v1/tracks/4vtyIW5uMCzu827nc5ThVt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vtyIW5uMCzu827nc5ThVt',
#   'duration_ms': 191396,
#   'time_signature': 1},
#  {'danceability': 0.32,
#   'energy': 0.319,
#   'key': 9,
#   'loudness': -9.807,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.804,
#   'instrumentalness': 0,
#   'liveness': 0.12,
#   'valence': 0.321,
#   'tempo': 174.853,
#   'type': 'audio_features',
#   'id': '6UKG36P9ExFQpmNNjoCX9X',
#   'uri': 'spotify:track:6UKG36P9ExFQpmNNjoCX9X',
#   'track_href': 'https://api.spotify.com/v1/tracks/6UKG36P9ExFQpmNNjoCX9X',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6UKG36P9ExFQpmNNjoCX9X',
#   'duration_ms': 224853,
#   'time_signature': 4}]
